# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
ch4gas = pd.read_excel('D:\\DataAnalytics\\Datasets\\Pollution_Temperature\\CH4_gas.xlsx')

# %%
ch4gas.head()
# Out:
#        Party      Base year           1990           1991           1992  \
# 0  Australia  119920.324771  119920.324771  119903.357596  119521.882123
# 1    Austria   10514.197071   10514.197071   10415.392014   10121.875276
# 2    Belarus   19704.280249   19704.280249   18864.158987   18101.604134
# 3    Belgium   12223.236900   12223.236900   12177.763676   12063.891890
# 4   Bulgaria   16869.489233   16179.057796   15146.306139   14832.587693
#
#             1993           1994           1995           1996           1997  \
# 0  116141.162112  112835.161161  111415.282562  111636.818671  114504.609579
# 1   10023.832475    9728.826343    9639.501592    9358.212652    8981.450171
# 2   17144.440057   16303.185370   15530.271370   15652.679560   15754.181800
# 3   12008.323715   12040.998682   12122.756642   11976.488573   11864.190209
# 4   13745.506767   11829.231459   11892.827987   11792.749306   11406.130800
#
# ...

# %%
ch4gas.tail()
# Out:
#                                                 Party      Base year  \
# 40                                        Switzerland    6102.333862
# 41                                             Turkey   41243.616825
# 42                                            Ukraine  190680.744451
# 43  United Kingdom of Great Britain and Northern I...  135330.833277
# 44                           United States of America  780794.622784
#
#              1990           1991           1992           1993           1994  \
# 40    6102.333862    6036.122174    5953.442070    5843.516717    5791.296379
# 41   41243.616825   42202.502916   42071.448854   41929.738946   41526.855512
# 42  190680.744451  182678.090818  172355.098633  163467.978272  153050.245873
# 43  135330.833277  136118.236275  135749.431172  134106.291650  127260.343667
# 44  780794.622784  785318.838133  784250.696562  769097.628893  772925.581622
#
#              1995           1996           1997  \
# ...

# %%
ch4gas.shape
# Out:
# (45, 29)

# %%
ch4gas.columns
# Out:
# Index([                                            'Party',
#                                                'Base year',
#                                                       1990,
#                                                       1991,
#                                                       1992,
#                                                       1993,
#                                                       1994,
#                                                       1995,
#                                                       1996,
#                                                       1997,
#                                                       1998,
#                                                       1999,
#                                                       2000,
#                                                       2001,
#                                                       2002,
#                                                       2003,
# ...

# %%
ch4gas.dtypes
# Out:
# Party                                                 object
# Base year                                            float64
# 1990                                                 float64
# 1991                                                 float64
# 1992                                                 float64
# 1993                                                 float64
# 1994                                                 float64
# 1995                                                 float64
# 1996                                                 float64
# 1997                                                 float64
# 1998                                                 float64
# 1999                                                 float64
# 2000                                                 float64
# 2001                                                 float64
# 2002                                                 float64
# ...

# %%
ch4gas.apply(lambda x: sum(x.isnull()))
# Out:
# Party                                                0
# Base year                                            0
# 1990                                                 0
# 1991                                                 0
# 1992                                                 0
# 1993                                                 0
# 1994                                                 0
# 1995                                                 0
# 1996                                                 0
# 1997                                                 0
# 1998                                                 0
# 1999                                                 0
# 2000                                                 0
# 2001                                                 0
# 2002                                                 0
# 2003                                                 0
# 2004                                                 0
# ...

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 10)

# %%
ch4gas.plot(kind='barh',x='Party',y=[1990,2000,2010])

# %%
ch4gas.plot(kind='line',x='Party',y=[1990,1995,2000,2005,2010])
plt.xticks(rotation=90)
# Out:
# (array([  0.,   5.,  10.,  15.,  20.,  25.,  30.,  35.,  40.,  45.]),
#  <a list of 10 Text xticklabel objects>)

# %%
ch4gas.drop('Base year',axis=1)
# Out:
#                                                 Party           1990  \
# 0                                           Australia  119920.324771
# 1                                             Austria   10514.197071
# 2                                             Belarus   19704.280249
# 3                                             Belgium   12223.236900
# 4                                            Bulgaria   16179.057796
# 5                                              Canada   93532.056409
# 6                                             Croatia    3744.189427
# 7                                              Cyprus     691.706622
# 8                                      Czech Republic   23450.867476
# 9                                             Denmark    7662.913342
# 10                                            Estonia    1909.607356
# 11                        European Union (Convention)  728408.462192
# 12                                European Union (KP)  729474.492770
# ...

# %%
ch4gas.plot(kind='barh',x='Party',y='Change from base year to latest reported year (%)')

# %%
ch4gas.drop('Last Inventory Year (2015)', axis=1)
# Out:
#                                                 Party      Base year  \
# 0                                           Australia  119920.324771
# 1                                             Austria   10514.197071
# 2                                             Belarus   19704.280249
# 3                                             Belgium   12223.236900
# 4                                            Bulgaria   16869.489233
# 5                                              Canada   93532.056409
# 6                                             Croatia    3744.189427
# 7                                              Cyprus     691.706622
# 8                                      Czech Republic   23450.867476
# 9                                             Denmark    7662.913342
# 10                                            Estonia    1909.607356
# 11                        European Union (Convention)  728408.462192
# 12                                European Union (KP)  729474.492770
# ...

# %%
ch4gas.columns
# Out:
# Index([                                            'Party',
#                                                'Base year',
#                                                       1990,
#                                                       1991,
#                                                       1992,
#                                                       1993,
#                                                       1994,
#                                                       1995,
#                                                       1996,
#                                                       1997,
#                                                       1998,
#                                                       1999,
#                                                       2000,
#                                                       2001,
#                                                       2002,
#                                                       2003,
# ...

# %%
for column in ch4gas.columns[2:-1]:
    print (ch4gas[column].mean())
    #print (np.log(ch4gas[column].mean()))
# Out:
# 101398.00739427954
# 98306.5695581738
# 94983.16065093229
# 92271.96022836736
# 89550.67479362147
# 88259.83265625765
# 87279.55148039885
# 85662.15186992117
# 83884.29151584106
# 82685.6705850182
# 82034.75685314603
# 81790.4833727861
# 80935.89443534908
# 81401.33665534267
# 80976.43867828156
# 80595.45060057162
# 80249.83154207394
# 80009.90386655612
# 79321.5508170954
# 77579.11677596139
# 77633.48876113107
# 77001.77704140004
# 76726.70273313863
# 75736.40832808899
# 75147.3409054552
# 74642.24757668146

# %%
ch4gas.set_index(['Party'])
# Out:
#                                                         Base year  \
# Party
# Australia                                           119920.324771
# Austria                                              10514.197071
# Belarus                                              19704.280249
# Belgium                                              12223.236900
# Bulgaria                                             16869.489233
# Canada                                               93532.056409
# Croatia                                               3744.189427
# Cyprus                                                 691.706622
# Czech Republic                                       23450.867476
# Denmark                                               7662.913342
# Estonia                                               1909.607356
# European Union (Convention)                         728408.462192
# European Union (KP)                                 729474.492770
# ...

# %%
index = ch4gas.index.tolist()

# %%
index.append('mean')

# %%
ch4gas.reindex(index)
# Out:
#                                                   Party      Base year  \
# 0                                             Australia  119920.324771
# 1                                               Austria   10514.197071
# 2                                               Belarus   19704.280249
# 3                                               Belgium   12223.236900
# 4                                              Bulgaria   16869.489233
# 5                                                Canada   93532.056409
# 6                                               Croatia    3744.189427
# 7                                                Cyprus     691.706622
# 8                                        Czech Republic   23450.867476
# 9                                               Denmark    7662.913342
# 10                                              Estonia    1909.607356
# 11                          European Union (Convention)  728408.462192
# ...

# %%
for column in ch4gas.columns[1:-2]:
    ch4gas.set_value('mean',column,ch4gas[column].mean())
    #ch4gas.loc['mean'] = ch4gas[column].mean()

# %%
ch4gas.tail()
# Out:
#                                                   Party      Base year  \
# 41                                               Turkey   41243.616825
# 42                                              Ukraine  190680.744451
# 43    United Kingdom of Great Britain and Northern I...  135330.833277
# 44                             United States of America  780794.622784
# mean                                            74653.5  101833.150149
#
#                1990           1991           1992           1993  \
# 41     41243.616825   42202.502916   42071.448854   41929.738946
# 42    190680.744451  182678.090818  172355.098633  163467.978272
# 43    135330.833277  136118.236275  135749.431172  134106.291650
# 44    780794.622784  785318.838133  784250.696562  769097.628893
# mean  101385.368221   98295.391367   94973.553069   92263.633932
#
#                1994           1995           1996           1997  \
# 41     41526.855512   41233.705626   41503.580997   40744.312284
# ...

# %%
ch4gas.loc['mean'][2:-2]
# Out:
# 1990     101385
# 1991    98295.4
# 1992    94973.6
# 1993    92263.6
# 1994    89543.6
# 1995    88253.4
# 1996    87273.6
# 1997    85656.9
# 1998    83879.9
# 1999    82681.9
# 2000    82031.3
# 2001    81787.1
# 2002    80932.9
# 2003    81398.1
# 2004    80973.5
# 2005    80592.6
# 2006    80247.2
# 2007    80007.4
# 2008    79319.3
# 2009    77577.7
# 2010    77632.1
# 2011    77000.7
# 2012    76725.7
# 2013    75735.9
# 2014    75147.1
# Name: mean, dtype: object

# %%
plt.plot(ch4gas.loc['mean'][2:-2])

# %%
temperature = pd.read_csv("D:\\DataAnalytics\\Datasets\\Pollution_Temperature\\cleanTemperatureData.csv")

# %%
temperature = temperature.loc[:,~temperature.columns.str.contains('Unnamed')]

# %%
temperature.head()
# Out:
#    Year   Jan   Feb   Mar   Apr    May    Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -84.0 -42.0 -49.0 -68.0  -37.0  -50.0 -49.0   5.0 -51.0 -69.0 -53.0
# 1  1881 -80.0 -63.0 -37.0 -28.0   -4.0 -113.0 -54.0 -26.0 -36.0 -50.0 -58.0
# 2  1882  11.0 -12.0  -9.0 -60.0  -38.0 -103.0 -71.0 -12.0  -8.0 -32.0 -40.0
# 3  1883 -69.0 -95.0 -46.0 -32.0  -36.0   44.0  -2.0 -16.0 -46.0 -58.0 -70.0
# 4  1884 -61.0 -35.0 -41.0 -95.0 -120.0  -83.0 -85.0  14.0 -37.0 -78.0 -82.0
#
#      Dec
# 0  -55.0
# 1  -16.0
# 2  -68.0
# 3  -40.0
# 4 -100.0

# %%
temperature.set_index(['Year'],inplace=True)

# %%
temperature['Mean'] = temperature.mean(axis=1)

# %%
temperature.head()
# Out:
#        Jan   Feb   Mar   Apr    May    Jun   Jul   Aug   Sep   Oct   Nov  \
# Year
# 1880 -84.0 -42.0 -49.0 -68.0  -37.0  -50.0 -49.0   5.0 -51.0 -69.0 -53.0
# 1881 -80.0 -63.0 -37.0 -28.0   -4.0 -113.0 -54.0 -26.0 -36.0 -50.0 -58.0
# 1882  11.0 -12.0  -9.0 -60.0  -38.0 -103.0 -71.0 -12.0  -8.0 -32.0 -40.0
# 1883 -69.0 -95.0 -46.0 -32.0  -36.0   44.0  -2.0 -16.0 -46.0 -58.0 -70.0
# 1884 -61.0 -35.0 -41.0 -95.0 -120.0  -83.0 -85.0  14.0 -37.0 -78.0 -82.0
#
#         Dec       Mean
# Year
# 1880  -55.0 -39.285714
# 1881  -16.0 -36.230769
# 1882  -68.0 -26.087912
# 1883  -40.0 -28.060440
# 1884 -100.0 -55.829670

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 10)
temperature.plot(kind='line',x=temperature.index,y='Mean')

# %%
plt.plot(temperature['Mean'][110:-3])

# %%
plt.plot(temperature['Mean'][110:-3],ch4gas.loc['mean'][2:-2])# negative relation Pollution and Temperature

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure().gca(projection='3d')

x = temperature.index[110:-3]
y = temperature['Mean'][110:-3]
z = ch4gas.loc['mean'][2:-2]

fig.scatter(x, y, z)

fig.set_xlabel('Year Index')
fig.set_ylabel('Temperature in Fahrenhiet')
fig.set_zlabel('CH4 Pollution in Kt')

plt.show()
